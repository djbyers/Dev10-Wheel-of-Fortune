# %%
#Store the word in an answer variable in all upper case

answer = "Nashville".upper()

#Store hint

hint1 = "American Sports Cities"

#Store guessed word as a mask of underscores

guessed = list("_" * len(answer))

# %%
#Create player list

player_list = {
    "player1": 0,
    "player2": 0,
    "player3": 0
}

# %%
#Create spin function

import random

def spin():
    wheel = ["Bankrupt", "Lose a Turn", 100, 100, 150, 200, 200, 250, 300, 300, 350, 400, 400, 450, 500, 500, 550, 600, 650, 700, 750, 800, 850, 900]
    result = random.choice(wheel)
    return result
    print(result)

# %%
#Create vowel list

vowels = ["A","E","I","O","U"]

# %%
print(hint1)
print(f" {' '.join(guessed)}")
# Out:
# American Sports Cities
#  _ _ _ _ _ _ _ _ _

# %%
#While there are still blanks in guessed:
while "_" in guessed:
    for key in player_list.keys():
        if key == "player1":
            print("Player 1, your turn.")
            print(player_list)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper
            #Make sure the guess is a word or letter
            if not question.isalpha():
                print("Please enter an alphabecital character.")
                continue
            #If the player wants to spin
            if question == "spin".upper:
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_list.update("player1":0)
                    print(player_list)
                    #Turn ends here
                    break
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_list)
                    #Turn ends here
                    break
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    #Make sure guess isn't a vowel
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        #Add correct value to score
                        player_list.update("player1": player_list.values()[0] + result*answer.count(guess))
                        #Reveal letters
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_list)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_list.update("player1": player_list.values()[0] + 500)
                            print(player_list)
                            break
                            #After a correct letter, either buy a vowel, solve, or end turn
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:"))
                        if turn == "vowel".upper:
                            #can only buy a vowel if the bank is at least 250
                            if player_list.values()[0] <250:
                                print("I'm sorry, you cannot afford a vowel")
                                #Can still try to solve here
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper:
                                    break
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_list.update("player1":player_list.values()[0] + 500)
                                        print(player_list)
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        break
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                #Make sure vowel is a vowel
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    #Subtract cost of vowel
                                    player_list.update("player1":player_list.values()[0] - 250)
                                    #Reveal letter
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                        if answer[counter] == guess:
                                            guessed[counter] = guess
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_list)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_list.update("player1": player_list.values()[0] + 500)
                                            print(player_list)
                                            break
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_list)
                                        break
                    
                    #If guess isn't in word
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_list)
                        break
            
            #If player chooses to solve right away
            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_list.update("player1", player_list.values()[0]+ 500)
                    print(player_list)
                    break
                else:
                    print(f"{guess} is not the word.")
                    print(player_list)
                    
                    
            if key == "player2":
            print("Player 2, your turn.")
            print(player_list)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper
            #Make sure the guess is a word or letter
            if not question.isalpha():
                print("Please enter an alphabecital character.")
                continue
            #If the player wants to spin
            if question == "spin".upper:
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_list.update("player2":0)
                    print(player_list)
                    #Turn ends here
                    break
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_list)
                    #Turn ends here
                    break
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        player_list.update("player2": player_list.values()[1] + result*answer.count(guess))
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_list)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_list.update("player2": player_list.values()[1] + 500)
                            print(player_list)
                            break
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:"))
                        if turn == "vowel".upper:
                            if player_list.values()[1] <250:
                                print("I'm sorry, you cannot afford a vowel")
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper:
                                    break
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_list.update("player2":player_list.values()[1] + 500)
                                        print(player_list)
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        break
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    player_list.update("player2":player_list.values()[1] - 250)
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                        if answer[counter] == guess:
                                            guessed[counter] = guess
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_list)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_list.update("player2": player_list.values()[1] + 500)
                                            print(player_list)
                                            break
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_list)
                                        break
                        
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_list)
                        break
                        
            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_list.update("player2", player_list.values()[1]+ 500)
                    print(player_list)
                    break
                else:
                    print(f"{guess} is not the word.")
                    print(player_list)
                    
                    
            if key == "player3":
            print("Player 3, your turn.")
            print(player_list)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper
            #Make sure the guess is a word or letter
            if not question.isalpha():
                print("Please enter an alphabecital character.")
                continue
            #If the player wants to spin
            if question == "spin".upper:
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_list.update("player3":0)
                    print(player_list)
                    #Turn ends here
                    break
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_list)
                    #Turn ends here
                    break
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        player_list.update("player3": player_list.values()[2] + result*answer.count(guess))
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_list)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_list.update("player3": player_list.values()[2] + 500)
                            print(player_list)
                            break
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:"))
                        if turn == "vowel".upper:
                            if player_list.values()[2] <250:
                                print("I'm sorry, you cannot afford a vowel")
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper:
                                    break
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_list.update("player3":player_list.values()[2] + 500)
                                        print(player_list)
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        break
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    player_list.update("player3":player_list.values()[2] - 250)
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                        if answer[counter] == guess:
                                            guessed[counter] = guess
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_list)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_list.update("player3": player_list.values()[2] + 500)
                                            print(player_list)
                                            break
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_list)
                                        break
                        
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_list)
                        break
                        
            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_list.update("player3", player_list.values()[2]+ 500)
                    print(player_list)
                    break
                else:
                    print(f"{guess} is not the word.")
                    print(player_list)
# Out:
#   File "C:\Users\djbye\AppData\Local\Temp/ipykernel_22484/198113257.py", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
#Store the word in an answer variable in all upper case

answer = "Djibouti".upper()

#Store hint

hint2 = "African Countries"

#Store guessed word as a mask of underscores

guessed = list("_" * len(answer))
# Out:
# 3

# %%
print(hint2)
print(f" {' '.join(guessed)}")
# Out:
# {'player1': 0, 'player2': 0, 'player3': 0}

# %%
#While there are still blanks in guessed:
while "_" in guessed:
    for key in player_list.keys():
        if key == "player1":
            print("Player 1, your turn.")
            print(player_list)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper
            #Make sure the guess is a word or letter
            if not question.isalpha():
                print("Please enter an alphabecital character.")
                continue
            #If the player wants to spin
            if question == "spin".upper:
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_list.update("player1":0)
                    print(player_list)
                    #Turn ends here
                    break
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_list)
                    #Turn ends here
                    break
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        player_list.update("player1": player_list.values()[0] + result*answer.count(guess))
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_list)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_list.update("player1": player_list.values()[0] + 500)
                            print(player_list)
                            break
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:"))
                        if turn == "vowel".upper:
                            if player_list.values()[0] <250:
                                print("I'm sorry, you cannot afford a vowel")
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper:
                                    break
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_list.update("player1":player_list.values()[0] + 500)
                                        print(player_list)
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        break
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    player_list.update("player1":player_list.values()[0] - 250)
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                        if answer[counter] == guess:
                                            guessed[counter] = guess
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_list)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_list.update("player1": player_list.values()[0] + 500)
                                            print(player_list)
                                            break
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_list)
                                        break
                        
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_list)
                        break
                        
            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_list.update("player1", player_list.values()[0]+ 500)
                    print(player_list)
                    break
                else:
                    print(f"{guess} is not the word.")
                    print(player_list)
                    
                    
            if key == "player2":
            print("Player 2, your turn.")
            print(player_list)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper
            #Make sure the guess is a word or letter
            if not question.isalpha():
                print("Please enter an alphabecital character.")
                continue
            #If the player wants to spin
            if question == "spin".upper:
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_list.update("player2":0)
                    print(player_list)
                    #Turn ends here
                    break
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_list)
                    #Turn ends here
                    break
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        player_list.update("player2": player_list.values()[1] + result*answer.count(guess))
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_list)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_list.update("player2": player_list.values()[1] + 500)
                            print(player_list)
                            break
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:"))
                        if turn == "vowel".upper:
                            if player_list.values()[1] <250:
                                print("I'm sorry, you cannot afford a vowel")
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper:
                                    break
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_list.update("player2":player_list.values()[1] + 500)
                                        print(player_list)
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        break
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    player_list.update("player2":player_list.values()[1] - 250)
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                        if answer[counter] == guess:
                                            guessed[counter] = guess
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_list)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_list.update("player2": player_list.values()[1] + 500)
                                            print(player_list)
                                            break
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_list)
                                        break
                        
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_list)
                        break
                        
            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_list.update("player2", player_list.values()[1]+ 500)
                    print(player_list)
                    break
                else:
                    print(f"{guess} is not the word.")
                    print(player_list)
                    
                    
            if key == "player3":
            print("Player 3, your turn.")
            print(player_list)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper
            #Make sure the guess is a word or letter
            if not question.isalpha():
                print("Please enter an alphabecital character.")
                continue
            #If the player wants to spin
            if question == "spin".upper:
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_list.update("player3":0)
                    print(player_list)
                    #Turn ends here
                    break
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_list)
                    #Turn ends here
                    break
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        player_list.update("player3": player_list.values()[2] + result*answer.count(guess))
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_list)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_list.update("player3": player_list.values()[2] + 500)
                            print(player_list)
                            break
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:"))
                        if turn == "vowel".upper:
                            if player_list.values()[2] <250:
                                print("I'm sorry, you cannot afford a vowel")
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper:
                                    break
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_list.update("player3":player_list.values()[2] + 500)
                                        print(player_list)
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        break
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    player_list.update("player3":player_list.values()[2] - 250)
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                        if answer[counter] == guess:
                                            guessed[counter] = guess
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_list)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_list.update("player3": player_list.values()[2] + 500)
                                            print(player_list)
                                            break
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_list)
                                        break
                        
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_list)
                        break
                        
            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_list.update("player3", player_list.values()[2]+ 500)
                    print(player_list)
                    break
                else:
                    print(f"{guess} is not the word.")
                    print(player_list)

# %%
winner = max(player_list.items)

print(f"Congradulations {winner[0]} on winning our game today with a total of ${winner[1]}! You will now move on to the bonus round!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22484/688276716.py in <module>
# ----> 1 winner = max(player_list.items)
#       2
#       3 print(f"Congradulations {winner[0]} on winning our game today with a total of ${winner[1]}! You will now move on to the bonus round!")
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
#Store the word in an answer variable in all upper case

answer = "Galadriel".upper()

#Store hint

hint3 = "Tolkien Characters"

#Store guessed word as a mask of underscores

guessed = list("_" * len(answer))

print(hint3)
print(f" {' '.join(guessed)}")
# Out:
# Tolkien Characters
#  _ _ _ _ _ _ _ _ _

# %%
print("You will be given the letters R, S, T, L, N, and E for free this round")

free = ["R", "S", "T", "L", "N", "E"]

for letter in free:
    if letter in answer:
        for counter in range(0, len(answer)):
            if answer[counter] == letter
            guessed[counter] = letter


print(f"The word so far is {guessed}.")

print("Choose three more consenants and one vowel:")

guess1 = str(input("First consenant:")).upper()
guess2 = str(input("Second consenant")).upper()
guess3 = str(input("Third consenant")).upper()
guess4 = str(input("Vowel:")).upper()

guesses = [guess1, guess2, guess3, guess4]

for letters in guesses:
     if letter in answer:
        for counter in range(0, len(answer)):
            if answer[counter] == letter:
            guessed[counter] = letter


print(f"The word so far is {guessed}.")

final = str(input("You get one guess to solve the puzzle:")).upper()

if final == answer:
    print(f"The answer is {answer}! You win the game and $100,000!")
    winner[1] = 100000
    print(winner)
else:
    print(f"I'm sorry, your guess of {final} was incorrect. The correct response was {answer}. However, you still walk away with your original 2 round total of ${winner[1]}!")
# Out:
#   File "C:\Users\djbye\AppData\Local\Temp/ipykernel_22484/4255515910.py", line 8
#     if answer[counter] == letter
#                                 ^
# SyntaxError: invalid syntax
