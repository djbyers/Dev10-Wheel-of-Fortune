# %%
#Store the word in an answer variable in all upper() case

answer = "Nashville".upper()

#Store hint

hint1 = "American Sports Cities"

#Store guessed word as a mask of underscores

guessed = list("_" * len(answer))

# %%
#Create player dictionary and score list

player_dict = {
    "player1": 0,
    "player2": 0,
    "player3": 0
}

player_score = [0,0,0]

# %%
#Create spin function

import random

def spin():
    wheel = ["Bankrupt", "Lose a Turn", 100, 100, 150, 200, 200, 250, 300, 300, 350, 400, 400, 450, 500, 500, 550, 600, 650, 700, 750, 800, 850, 900]
    result = random.choice(wheel)
    return result
    print(result)

# %%
#Create vowel list

vowels = ["A","E","I","O","U"]

# %%
print(hint1)
print(f" {' '.join(guessed)}")
# Out:
# American Sports Cities
#  _ _ _ _ _ _ _ _ _

# %%
#While there are still blanks in guessed:
while "_" in guessed:
    for key in player_dict.keys():
        if key == "player1":
            print("Player 1, your turn.")
            print(player_dict)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper()

            #If the player wants to spin
            if question == "spin".upper():
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_dict.update({"player1":0})
                    print(player_dict)
                    #Turn ends here
                    continue
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_dict)
                    #Turn ends here
                    continue
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    #Make sure guess isn't a vowel
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        #Add correct value to score
                        player_score[0] = player_score[0] + result*answer.count(guess)
                        player_dict["player1"] = player_score[0]
                        #Reveal letters
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_dict)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_score[0] = player_score[0] + 500
                            player_dict["player1"] = player_score[0]
                            print(player_dict)
                            continue
                            #After a correct letter, either buy a vowel, solve, or end turn
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:")).upper()
                        if turn == "vowel".upper():
                            #can only buy a vowel if the bank is at least 250
                            if player_score[0] <250:
                                print("I'm sorry, you cannot afford a vowel.")
                                #Can still try to solve here
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper():
                                    continue
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_score[0] = player_score[0] + 500
                                        player_dict["player1"] = player_score[0]
                                        print(player_dict)
                                        guessed = answer 
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        continue
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                #Make sure vowel is a vowel
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    #Subtract cost of vowel
                                    player_score[0] = player_score[0] - 250
                                    player_dict["player1"] = player_score[0]
                                    #Reveal letter
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                            if answer[counter] == vow:
                                                guessed[counter] = vow
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_dict)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_score[0] = player_score[0] + 500
                                            player_dict["player1"] = player_score[0] 
                                            print(player_dict)
                                            continue
                                        word = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                        if word == "pass".upper():
                                            continue
                                        else:
                                            if word == answer:
                                                print(f"The word is {answer}. You win this round!")
                                                player_score[0] = player_score[0] + 500
                                                player_dict["player1"] = player_score[0]
                                                print(player_dict)
                                                guessed = answer
                                                
                                                break
                                            else:
                                                print(f"{word} is not the answer.")
                                                continue
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_dict)
                                        continue
                        elif turn == "pass".upper():
                            continue
                        
                        else:
                            if turn == answer:
                                print(f"The word is {answer}. You win this round!")
                                player_score[0] = player_score[0] + 500
                                player_dict["player1"] = player_score[0]
                                print(player_dict)
                                guessed = answer
                                break
                            else:
                                print(f"{turn} is not the answer.")
                                print(player_dict)
                                continue
                    #If guess isn't in word
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_dict)
                        continue
            
            #If player chooses to solve right away

            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_score[0] = player_score[0] + 500
                    player_dict["player1"] = player_score[0]
                    print(player_dict)
                    guessed = answer
                    
                    break
                else:
                    print(f"{question} is not the word.")
                    print(player_dict)
                    
                    
        if key == "player2":
            print("Player 2, your turn.")
            print(player_dict)
            
            #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper()

            #If the player wants to spin
            if question == "spin".upper():
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_dict.update({"player2":0})
                    print(player_dict)
                    #Turn ends here
                    continue
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_dict)
                    #Turn ends here
                    continue
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    #Make sure guess isn't a vowel
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        #Add correct value to score
                        player_score[1] = player_score[1] + result*answer.count(guess)
                        player_dict["player2"] = player_score[1]
                        #Reveal letters
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_dict)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_score[1] = player_score[1] + 500
                            player_dict["player2"] = player_score[1]
                            print(player_dict)
                            continue
                            #After a correct letter, either buy a vowel, solve, or end turn
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:")).upper()
                        if turn == "vowel".upper():
                            #can only buy a vowel if the bank is at least 250
                            if player_score[1] <250:
                                print("I'm sorry, you cannot afford a vowel.")
                                #Can still try to solve here
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper():
                                    continue
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_score[1] = player_score[1] + 500
                                        player_dict["player2"] = player_score[1]
                                        print(player_dict)
                                        guessed = answer 
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        continue
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                #Make sure vowel is a vowel
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    #Subtract cost of vowel
                                    player_score[1] = player_score[1] - 250
                                    player_dict["player2"] = player_score[1]
                                    #Reveal letter
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                            if answer[counter] == vow:
                                                guessed[counter] = vow
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_dict)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_score[1] = player_score[1] + 500
                                            player_dict["player2"] = player_score[1] 
                                            print(player_dict)
                                            continue
                                        word = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                        if word == "pass".upper():
                                            continue
                                        else:
                                            if word == answer:
                                                print(f"The word is {answer}. You win this round!")
                                                player_score[1] = player_score[1] + 500
                                                player_dict["player2"] = player_score[1]
                                                print(player_dict)
                                                guessed = answer
                                                
                                                break
                                            else:
                                                print(f"{word} is not the answer.")
                                                continue
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_dict)
                                        continue
                        elif turn == "pass".upper():
                            continue
                        
                        else:
                            if turn == answer:
                                print(f"The word is {answer}. You win this round!")
                                player_score[1] = player_score[1] + 500
                                player_dict["player2"] = player_score[1]
                                print(player_dict)
                                guessed = answer
                                break
                            else:
                                print(f"{turn} is not the answer.")
                                print(player_dict)
                                continue
                    #If guess isn't in word
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_dict)
                        continue
            
            #If player chooses to solve right away

            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_score[1] = player_score[1] + 500
                    player_dict["player2"] = player_score[1]
                    print(player_dict)
                    guessed = answer
                    
                    break
                else:
                    print(f"{question} is not the word.")
                    print(player_dict)

                    
                    
        if key == "player3":
            print("Player 3, your turn.")
            print(player_dict)
            #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper()

            #If the player wants to spin
            if question == "spin".upper():
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_dict.update({"player3":0})
                    print(player_dict)
                    #Turn ends here
                    continue
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_dict)
                    #Turn ends here
                    continue
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    #Make sure guess isn't a vowel
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        #Add correct value to score
                        player_score[2] = player_score[2] + result*answer.count(guess)
                        player_dict["player3"] = player_score[2]
                        #Reveal letters
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_dict)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_score[2] = player_score[2] + 500
                            player_dict["player3"] = player_score[2]
                            print(player_dict)
                            continue
                            #After a correct letter, either buy a vowel, solve, or end turn
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:")).upper()
                        if turn == "vowel".upper():
                            #can only buy a vowel if the bank is at least 250
                            if player_score[2] <250:
                                print("I'm sorry, you cannot afford a vowel.")
                                #Can still try to solve here
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper():
                                    continue
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_score[2] = player_score[2] + 500
                                        player_dict["player3"] = player_score[2]
                                        print(player_dict)
                                        guessed = answer 
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        continue
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                #Make sure vowel is a vowel
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    #Subtract cost of vowel
                                    player_score[2] = player_score[2] - 250
                                    player_dict["player3"] = player_score[2]
                                    #Reveal letter
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                            if answer[counter] == vow:
                                                guessed[counter] = vow
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_dict)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_score[2] = player_score[2] + 500
                                            player_dict["player3"] = player_score[2] 
                                            print(player_dict)
                                            continue
                                        word = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                        if word == "pass".upper():
                                            continue
                                        else:
                                            if word == answer:
                                                print(f"The word is {answer}. You win this round!")
                                                player_score[2] = player_score[2] + 500
                                                player_dict["player3"] = player_score[2]
                                                print(player_dict)
                                                guessed = answer
                                                
                                                break
                                            else:
                                                print(f"{word} is not the answer.")
                                                continue
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_dict)
                                        continue
                        elif turn == "pass".upper():
                            continue
                        
                        else:
                            if turn == answer:
                                print(f"The word is {answer}. You win this round!")
                                player_score[2] = player_score[2] + 500
                                player_dict["player3"] = player_score[2]
                                print(player_dict)
                                guessed = answer
                                break
                            else:
                                print(f"{turn} is not the answer.")
                                print(player_dict)
                                continue
                    #If guess isn't in word
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_dict)
                        continue
            
            #If player chooses to solve right away

            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_score[2] = player_score[2] + 500
                    player_dict["player3"] = player_score[2]
                    print(player_dict)
                    guessed = answer
                    break
                else:
                    print(f"{question} is not the word.")
                    print(player_dict)
# Out:
# Player 1, your turn.
# {'player1': 0, 'player2': 0, 'player3': 0}
# Attempt to solve the puzzle or type 'spin': nashville
# The word is NASHVILLE. You win this round!
# {'player1': 500, 'player2': 0, 'player3': 0}

# %%
print(guessed)
# Out:
# NASHVILLE

# %%
#Store the word in an answer variable in all upper() case

answer = "Djibouti".upper()

#Store hint

hint2 = "African Countries"

#Store guessed word as a mask of underscores

guessed = list("_" * len(answer))

# %%
print(hint2)
print(f" {' '.join(guessed)}")
# Out:
# African Countries
#  _ _ _ _ _ _ _ _

# %%
#While there are still blanks in guessed:
while "_" in guessed:
    for key in player_dict.keys():
        if key == "player1":
            print("Player 1, your turn.")
            print(player_dict)
        #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper()

            #If the player wants to spin
            if question == "spin".upper():
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_dict.update({"player1":0})
                    print(player_dict)
                    #Turn ends here
                    continue
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_dict)
                    #Turn ends here
                    continue
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    #Make sure guess isn't a vowel
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        #Add correct value to score
                        player_score[0] = player_score[0] + result*answer.count(guess)
                        player_dict["player1"] = player_score[0]
                        #Reveal letters
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_dict)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_score[0] = player_score[0] + 500
                            player_dict["player1"] = player_score[0]
                            print(player_dict)
                            continue
                            #After a correct letter, either buy a vowel, solve, or end turn
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:")).upper()
                        if turn == "vowel".upper():
                            #can only buy a vowel if the bank is at least 250
                            if player_score[0] <250:
                                print("I'm sorry, you cannot afford a vowel.")
                                #Can still try to solve here
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper():
                                    continue
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_score[0] = player_score[0] + 500
                                        player_dict["player1"] = player_score[0]
                                        print(player_dict)
                                        guessed = answer 
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        continue
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                #Make sure vowel is a vowel
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    #Subtract cost of vowel
                                    player_score[0] = player_score[0] - 250
                                    player_dict["player1"] = player_score[0]
                                    #Reveal letter
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                            if answer[counter] == vow:
                                                guessed[counter] = vow
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_dict)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_score[0] = player_score[0] + 500
                                            player_dict["player1"] = player_score[0] 
                                            print(player_dict)
                                            continue
                                        word = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                        if word == "pass".upper():
                                            continue
                                        else:
                                            if word == answer:
                                                print(f"The word is {answer}. You win this round!")
                                                player_score[0] = player_score[0] + 500
                                                player_dict["player1"] = player_score[0]
                                                print(player_dict)
                                                guessed = answer
                                                
                                                break
                                            else:
                                                print(f"{word} is not the answer.")
                                                continue
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_dict)
                                        continue
                        elif turn == "pass".upper():
                            continue
                        
                        else:
                            if turn == answer:
                                print(f"The word is {answer}. You win this round!")
                                player_score[0] = player_score[0] + 500
                                player_dict["player1"] = player_score[0]
                                print(player_dict)
                                guessed = answer
                                break
                            else:
                                print(f"{turn} is not the answer.")
                                print(player_dict)
                                continue
                    #If guess isn't in word
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_dict)
                        continue
            
            #If player chooses to solve right away

            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_score[0] = player_score[0] + 500
                    player_dict["player1"] = player_score[0]
                    print(player_dict)
                    guessed = answer
                    
                    break
                else:
                    print(f"{question} is not the word.")
                    print(player_dict)
                    
                    
        if key == "player2":
            print("Player 2, your turn.")
            print(player_dict)
            
            #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper()

            #If the player wants to spin
            if question == "spin".upper():
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_dict.update({"player2":0})
                    print(player_dict)
                    #Turn ends here
                    continue
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_dict)
                    #Turn ends here
                    continue
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    #Make sure guess isn't a vowel
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        #Add correct value to score
                        player_score[1] = player_score[1] + result*answer.count(guess)
                        player_dict["player2"] = player_score[1]
                        #Reveal letters
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_dict)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_score[1] = player_score[1] + 500
                            player_dict["player2"] = player_score[1]
                            print(player_dict)
                            continue
                            #After a correct letter, either buy a vowel, solve, or end turn
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:")).upper()
                        if turn == "vowel".upper():
                            #can only buy a vowel if the bank is at least 250
                            if player_score[1] <250:
                                print("I'm sorry, you cannot afford a vowel.")
                                #Can still try to solve here
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper():
                                    continue
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_score[1] = player_score[1] + 500
                                        player_dict["player2"] = player_score[1]
                                        print(player_dict)
                                        guessed = answer 
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        continue
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                #Make sure vowel is a vowel
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    #Subtract cost of vowel
                                    player_score[1] = player_score[1] - 250
                                    player_dict["player2"] = player_score[1]
                                    #Reveal letter
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                            if answer[counter] == vow:
                                                guessed[counter] = vow
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_dict)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_score[1] = player_score[1] + 500
                                            player_dict["player2"] = player_score[1] 
                                            print(player_dict)
                                            continue
                                        word = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                        if word == "pass".upper():
                                            continue
                                        else:
                                            if word == answer:
                                                print(f"The word is {answer}. You win this round!")
                                                player_score[1] = player_score[1] + 500
                                                player_dict["player2"] = player_score[1]
                                                print(player_dict)
                                                guessed = answer
                                                
                                                break
                                            else:
                                                print(f"{word} is not the answer.")
                                                continue
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_dict)
                                        continue
                        elif turn == "pass".upper():
                            continue
                        
                        else:
                            if turn == answer:
                                print(f"The word is {answer}. You win this round!")
                                player_score[1] = player_score[1] + 500
                                player_dict["player2"] = player_score[1]
                                print(player_dict)
                                guessed = answer
                                break
                            else:
                                print(f"{turn} is not the answer.")
                                print(player_dict)
                                continue
                    #If guess isn't in word
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_dict)
                        continue
            
            #If player chooses to solve right away

            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_score[1] = player_score[1] + 500
                    player_dict["player2"] = player_score[1]
                    print(player_dict)
                    guessed = answer
                    
                    break
                else:
                    print(f"{question} is not the word.")
                    print(player_dict)

                    
                    
        if key == "player3":
            print("Player 3, your turn.")
            print(player_dict)
            #Ask the player if they want to solve the puzzle or spin:
            question = str(input("Attempt to solve the puzzle or type 'spin':")).upper()

            #If the player wants to spin
            if question == "spin".upper():
                result = spin()
                if result == "Bankrupt":
                    print("You spun Bankrupt!")
                    player_dict.update({"player3":0})
                    print(player_dict)
                    #Turn ends here
                    continue
                elif result == "Lose a Turn":
                    print("You spun Lose a Turn!")
                    print(player_dict)
                    #Turn ends here
                    continue
                else: 
                    print(f"You spun ${result}!")
                    guess = str(input("Guess a consenant:")).upper()
                    #Make sure guess isn't a vowel
                    if guess in vowels:
                        print("That is not a consenant. Try again:")
                        continue
                    if guess in answer:
                        print(f"{guess} is in the word.")
                        #Add correct value to score
                        player_score[2] = player_score[2] + result*answer.count(guess)
                        player_dict["player3"] = player_score[2]
                        #Reveal letters
                        for counter in range(0,len(answer)):
                            if answer[counter] == guess:
                                guessed[counter] = guess
                        print(f"The word guessed so far is {' '.join(guessed)}.")
                        print(player_dict)
                        if ''.join(guessed)== answer:
                            print(f"The word is {answer}. You win this round!")
                            player_score[2] = player_score[2] + 500
                            player_dict["player3"] = player_score[2]
                            print(player_dict)
                            continue
                            #After a correct letter, either buy a vowel, solve, or end turn
                        turn = str(input("Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer:")).upper()
                        if turn == "vowel".upper():
                            #can only buy a vowel if the bank is at least 250
                            if player_score[2] <250:
                                print("I'm sorry, you cannot afford a vowel.")
                                #Can still try to solve here
                                sovle = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                if solve == "pass".upper():
                                    continue
                                else:
                                    if solve == answer:
                                        print(f"The word is {answer}. You win this round!")
                                        player_score[2] = player_score[2] + 500
                                        player_dict["player3"] = player_score[2]
                                        print(player_dict)
                                        guessed = answer 
                                        break
                                    else:
                                        print(f"{solve} is not the answer.")
                                        continue
                            else:
                                vow = str(input("Guess a vowel:")).upper()
                                #Make sure vowel is a vowel
                                if vow not in vowels:
                                    print("That is now a vowel.")
                                    continue
                                else:
                                    #Subtract cost of vowel
                                    player_score[2] = player_score[2] - 250
                                    player_dict["player3"] = player_score[2]
                                    #Reveal letter
                                    if vow in answer:
                                        print(f"{vow} is in the word")
                                        for counter in range(0,len(answer)):
                                            if answer[counter] == vow:
                                                guessed[counter] = vow
                                        print(f"The word guessed so far is {' '.join(guessed)}.")
                                        print(player_dict)
                                        if ''.join(guessed)== answer:
                                            print(f"The word is {answer}. You win this round!")
                                            player_score[2] = player_score[2] + 500
                                            player_dict["player3"] = player_score[2] 
                                            print(player_dict)
                                            continue
                                        word = str(input("Type 'pass' to end your turn or guess the answer:")).upper()
                                        if word == "pass".upper():
                                            continue
                                        else:
                                            if word == answer:
                                                print(f"The word is {answer}. You win this round!")
                                                player_score[2] = player_score[2] + 500
                                                player_dict["player3"] = player_score[2]
                                                print(player_dict)
                                                guessed = answer
                                                
                                                break
                                            else:
                                                print(f"{word} is not the answer.")
                                                continue
                                    else:
                                        print(f"{vow} is not in the word.")
                                        print(player_dict)
                                        continue
                        elif turn == "pass".upper():
                            continue
                        
                        else:
                            if turn == answer:
                                print(f"The word is {answer}. You win this round!")
                                player_score[2] = player_score[2] + 500
                                player_dict["player3"] = player_score[2]
                                print(player_dict)
                                guessed = answer
                                break
                            else:
                                print(f"{turn} is not the answer.")
                                print(player_dict)
                                continue
                    #If guess isn't in word
                    else:
                        print(f"{guess} is not in the word.")
                        print(player_dict)
                        continue
            
            #If player chooses to solve right away

            else:
                if question == answer:
                    print(f"The word is {answer}. You win this round!")
                    player_score[2] = player_score[2] + 500
                    player_dict["player3"] = player_score[2]
                    print(player_dict)
                    guessed = answer
                    break
                else:
                    print(f"{question} is not the word.")
                    print(player_dict)
# Out:
# Player 1, your turn.
# {'player1': 0, 'player2': 500, 'player3': 0}
# Attempt to solve the puzzle or type 'spin': spin
# You spun $500!
# Guess a consenant: j
# J is in the word.
# The word guessed so far is _ J _ _ _ _ _ _.
# {'player1': 500, 'player2': 500, 'player3': 0}
# Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer: pass
# Player 2, your turn.
# {'player1': 500, 'player2': 500, 'player3': 0}
# Attempt to solve the puzzle or type 'spin': spin
# You spun $900!
# Guess a consenant: b
# B is in the word.
# The word guessed so far is _ J _ B _ _ _ _.
# {'player1': 500, 'player2': 1400, 'player3': 0}
# Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer: vowel
# Guess a vowel: i
# I is in the word
# The word guessed so far is _ J I B _ _ _ I.
# {'player1': 500, 'player2': 1150, 'player3': 0}
# Type 'pass' to end your turn or guess the answer: pass
# Player 3, your turn.
# {'player1': 500, 'player2': 1150, 'player3': 0}
# Attempt to solve the puzzle or type 'spin': spin
# You spun $650!
# Guess a consenant: d
# D is in the word.
# The word guessed so far is D J I B _ _ _ I.
# {'player1': 500, 'player2': 1150, 'player3': 650}
# Type 'vowel' to buy a vowel, 'pass' to end your turn, or guess the answer: djibouti
# The word is DJIBOUTI. You win this round!
# {'player1': 500, 'player2': 1150, 'player3': 1150}

# %%
list1 = list(player_dict.values())
amount = max(list1)
index = list1.index(amount)
list2 = list(player_dict.keys())
player = list2[index]

winner = [player, amount]


print(f"Congradulations {winner[0]} on winning our game today with a total of ${winner[1]}! You will now move on to the bonus round!")
# Out:
# Congradulations player2 on winning our game today with a total of $1150! You will now move on to the bonus round!

# %%
#Store the word in an answer variable in all upper() case

answer = "Galadriel".upper()

#Store hint

hint3 = "Tolkien Characters"

#Store guessed word as a mask of underscores

guessed = list("_" * len(answer))

print(hint3)
print(f" {' '.join(guessed)}")
# Out:
# Tolkien Characters
#  _ _ _ _ _ _ _ _ _

# %%
print("You will be given the letters R, S, T, L, N, and E for free this round")

free = ["R", "S", "T", "L", "N", "E"]

for letter in free:
    if letter in answer:
        for counter in range(0, len(answer)):
            if answer[counter] == letter:
                guessed[counter] = letter


print(f"The word so far is {guessed}.")

print("Choose three more consenants and one vowel:")

guess1 = str(input("First consenant:")).upper()
guess2 = str(input("Second consenant")).upper()
guess3 = str(input("Third consenant")).upper()
guess4 = str(input("Vowel:")).upper()

guesses = [guess1, guess2, guess3, guess4]

for letter in guesses:
     if letter in answer:
        for counter in range(0, len(answer)):
            if answer[counter] == letter:
                guessed[counter] = letter


print(f"The word so far is {guessed}.")

final = str(input("You get one guess to solve the puzzle:")).upper()

if final == answer:
    print(f"The answer is {answer}! You win the game and $100,000!")
    winner[1] = 100000
    print(winner)
else:
    print(f"I'm sorry, your guess of {final} was incorrect. The correct response was {answer}. However, you still walk away with your original 2 round total of ${winner[1]}!")
# Out:
# You will be given the letters R, S, T, L, N, and E for free this round
# The word so far is ['_', '_', 'L', '_', '_', 'R', '_', 'E', 'L'].
# Choose three more consenants and one vowel:
# First consenant: g
# Second consenant d
# Third consenant k
# Vowel: a
# The word so far is ['G', 'A', 'L', 'A', 'D', 'R', '_', 'E', 'L'].
# You get one guess to solve the puzzle: galadriel
# The answer is GALADRIEL! You win the game and $100,000!
# ['player2', 100000]
